# %% [markdown]
# #### Simple Quiz Game
# * **What it does:**
# * Asks multiple questions
# * Takes user answers
# * Calculates score
# * Displays result
#
# **Concepts used:**
# * Loops → question flow
# * Conditionals → answer checking
# * Functions → ask_question(), calculate_score()

# %%
def gameintro():
    print("---- WELCOME TO OUR GAME ----")
    print()
    print("You will be asked a few questions along with four options, you have to choose the correct option.")
    print("If you choose the right answer, your score increases, else it will be zero till you earn a point.")
    print("Player with maximum score will be the winner!!!!")
    print("Let's start the game!!!!")

print()

def q1():
    print("Q1] Give MCQ-style questions?")
    print("A] .pt")
    print("B] .python")
    print("C] .py")
    print("D] .pyt")
    choice = input("Enter your option:").upper()
    if choice == "C":
        result = 1
        print("Wow, you scored a point!!!!")
    else:
        result = 0
        print("Wrong answer")

    print()
    print("--------------------------------------------------------")
    print()
    return result
    
def q2():
    print("Q2] Which keyword is used to define a function in Python?")
    print("A] function")
    print("B] define")
    print("C] def")
    print("D] fun")
    choice = input("Enter your option:").upper()
    if choice == "C":
        print("Wow, you scored a point")
        result = 1
    else:
        print("Wrong answer")
        result = 0

    print()
    print("--------------------------------------------------------")
    print()
    return result

def q3():
    print("Q3] Which symbol is used for single-line comments in Python?")
    print("A] //")
    print("B] #")
    print("C] /* */")
    print("D] --")
    choice = input("Enter your option:").upper()
    if choice == "B":
        print("Wow, you scored a point")
        result = 1
    else:
        print("Wrong answer")
        result = 0

    print()
    print("--------------------------------------------------------")
    print()
    return result

def q4():
    print("Q4] What is the output of print(10 % 3)?")
    print("A] 3")
    print("B] 1")
    print("C] 0")
    print("D] 10")
    choice = input("Enter your option:").upper()
    if choice == "B":
        print("Wow, you scored a point")
        result = 1
    else:
        print("Wrong answer")
        result = 0
        
    print()
    print("--------------------------------------------------------")
    print()
    return result

def q5():
    print("Q5] Which data type stores True or False values?")
    print("A) int")
    print("B) float")
    print("C) str")
    print("D) bool")
    choice = input("Enter your option:").upper()
    if choice == "D":
        print("Wow, you scored a point")
        result = 1
    else:
        print("Wrong answer")
        result = 0
        
    print()
    print("--------------------------------------------------------")
    print()
    return result

def q6():
    print("Q6] Which loop is best when the number of iterations is known?")
    print("A) while")
    print("B) do-while")
    print("C) for")
    print("D) repeat")
    choice = input("Enter your option:").upper()
    if choice == "C":
        print("Wow, you scored a point")
        result = 1
    else:
        print("Wrong answer")
        result = 0
        
    print()
    print("--------------------------------------------------------")
    print()
    return result

def q7():
    print("Q7] What is the output of print(2 ** 4)?")
    print("A) 6")
    print("B) 8")
    print("C) 16")
    print("D) 4")
    choice = input("Enter your option:").upper()
    if choice == "C":
        print("Wow, you scored a point")
        result = 1
    else:
        print("Wrong answer")
        result = 0
        
    print()
    print("--------------------------------------------------------")
    print()
    return result

def q8():
    print("Q8] What is the capital of India?")
    print("A) Mumbai")
    print("B) Delhi")
    print("C) New Delhi")
    print("D) Chennai")
    choice = input("Enter your option:").upper()
    if choice == "C":
        print("Wow, you scored a point")
        result = 1
    else:
        print("Wrong answer")
        result = 0
        
    print()
    print("--------------------------------------------------------")
    print()
    return result

def q9():
    print("Q9] Which keyword is used to terminate a loop?")
    print("A) stop")
    print("B) exit")
    print("C) break")
    print("D) end")
    choice = input("Enter your option:").upper()
    if choice == "C":
        print("Wow, you scored a point")
        result = 1
    else:
        print("Wrong answer")
        result = 0
        
    print()
    print("--------------------------------------------------------")
    print()
    return result

def q10():
    print("Q10] Which keyword skips the current iteration and continues with the next one?")
    print("A) skip")
    print("B) pass")
    print("C) continue")
    print("D) next")
    choice = input("Enter your option:").upper()
    if choice == "C":
        print("Wow, you scored a point")
        result = 1
    else:
        print("Wrong answer")
        result = 0

    print()
    print("--------------------------------------------------------")
    print()
    return result

def total_score():
    score = 0
    score = score + q1()
    score = score + q2()
    score = score + q3()
    score = score + q4()
    score = score + q5()
    score = score + q6()
    score = score + q7()
    score = score + q8()
    score = score + q9()
    score = score + q10()
    return score

def main():
    gameintro()
    final_score = total_score()
    print("Your total score is:",final_score)
    if final_score >= 5:
        print("Congrats, You are the winner!!!")
    else:
        print("Better Luck next time!!")

main()
# Out:
# ---- WELCOME TO OUR GAME ----
#
# You will be asked a few questions along with four options, you have to choose the correct option.
# If you choose the right answer, your score increases, else it will be zero till you earn a point.
# Player with maximum score will be the winner!!!!
# Let's start the game!!!!
# Q1] Give MCQ-style questions?
# A] .pt
# B] .python
# C] .py
# D] .pyt
# Enter your option: c
# Wow, you scored a point!!!!
#
# --------------------------------------------------------
#
# Q2] Which keyword is used to define a function in Python?
# A] function
# B] define
# C] def
# D] fun
# Enter your option: c
# Wow, you scored a point
#
# --------------------------------------------------------
#
# Q3] Which symbol is used for single-line comments in Python?
# A] //
# B] #
# C] /* */
# D] --
# Enter your option: b
# Wow, you scored a point
#
# --------------------------------------------------------
#
# Q4] What is the output of print(10 % 3)?
# A] 3
# B] 1
# C] 0
# D] 10
# ...
