# %% [markdown]
# ## PROJECT ON ATM SIMULATION
# * What it does:
# * Check balance
# * Deposit money
# * Withdraw money
# * Exit
#
# **Concepts used:**
# * While loop → menu-driven program
# * Conditionals → choice handling
# * Functions → check_balance(), deposit(), withdraw()

# %%
def menu():
    while True:
        print("\n")
        print("---- MENU IS ----")
        print()
        print("1] Check balance")
        print()
        print("2] Deposit Money")
        print()
        print("3] Withdraw Money")
        print()
        print("4] Exit Simulation")
        print()
        choice = int(input("Enter your choice:"))
        if choice == 1:
            check_bal()
        elif choice == 2:
            deposit_money()
        elif choice == 3:
            withdraw_money()
        elif choice == 4:
            print("Exiting the simulation....")
            break
        else:
            print("Enter valid choice")
            
bal = 5000
def check_bal():
    print("Your current balance is:",bal)

def deposit_money():
    global bal
    amt = int(input("Enter the amount:"))
    if amt > 0:
        bal = bal + amt
        print(f"balance money is: {bal}.")
    else:
        print("Enter valid money amount")

def withdraw_money():
    global bal
    amt2 = int(input("Enter the money amount to withdraw:"))
    if amt2 <= 0:
        print("enter proper amount")
    elif amt2 > bal:
        print("not enough balance")
    else:
        new_bal = bal - amt2
        print("your new balance is:",new_bal)
        print("please take your money!!")

def __main__():
    menu()
__main__()
# Out:
# ---- MENU IS ----
#
# 1] Check balance
#
# 2] Deposit Money
#
# 3] Withdraw Money
#
# 4] Exit Simulation
# Enter your choice: 1
# Your current balance is: 5000
#
#
# ---- MENU IS ----
#
# 1] Check balance
#
# 2] Deposit Money
#
# 3] Withdraw Money
#
# 4] Exit Simulation
# Enter your choice: 2
# Enter the amount: 5320
# balance money is: 10320.
#
#
# ---- MENU IS ----
#
# 1] Check balance
#
# 2] Deposit Money
#
# 3] Withdraw Money
#
# 4] Exit Simulation
# Enter your choice: 3
# Enter the money amount to withdraw: 6540
# your new balance is: 3780
# please take your money!!
#
#
# ---- MENU IS ----
#
# 1] Check balance
#
# 2] Deposit Money
#
# 3] Withdraw Money
#
# 4] Exit Simulation
# Enter your choice: 4
# Exiting the simulation....
